# %%
import pandas as pd

# Using double backslashes
df = pd.read_excel("/Users/e410675/Library/CloudStorage/OneDrive-LondonSouthBankUniversity/LSBU - Jose's Collaborative Projects/Norfolk and Waveney CHPPD/2025 November/Data Engineering/Data/1-NHS England trust level CHPPD - data combined.xlsx")

# %%
df
# Out:
#                                        Organisation Name Organisation Code  \
# 0      CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION ...               RGT
# 1      BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...               RF4
# 2           MOORFIELDS EYE HOSPITAL NHS FOUNDATION TRUST               RP6
# 3      WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...               RBL
# 4                            MEDWAY NHS FOUNDATION TRUST               RPA
# ...                                                  ...               ...
# 10522                Central London Community Healthcare               RYX
# 10523                              Kent Community Health               RYY
# 10524                             Bradford District Care               TAD
# 10525                               Camden And Islington               TAF
# 10526                   Sheffield Health And Social Care               TAH
#
#        CHPPD - Overall  \
# 0                 9.11
# ...

# %%
# Group by 'Organisation Code' and find the most frequent 'Organisation Name' for each code
standard_names = (df.groupby(['Organisation Code', 'Organisation Name'])
                  .size()
                  .reset_index(name='count')
                  .sort_values(by=['Organisation Code', 'count'], ascending=[True, False])
                  .drop_duplicates(subset=['Organisation Code'])
                  .set_index('Organisation Code')['Organisation Name'])

# Create a mapping dictionary from the standard names
name_mapping = standard_names.to_dict()

# Replace the 'Organisation Name' column with the standardized names
df['Organisation Name'] = df['Organisation Code'].map(name_mapping)

# %%
# Create a new column for 'Year' and 'Month' extracted from the 'year_month' column
df['Year'] = pd.to_datetime(df['year_month']).dt.year
df['Month'] = pd.to_datetime(df['year_month']).dt.month

# If you want a single column for Year and Month as "YYYY-MM"
df['Year_Month'] = pd.to_datetime(df['year_month']).dt.to_period('M')

# %%
# Save the cleaned dataset or display it
df.to_excel(r"/Users/e410675/Library/CloudStorage/OneDrive-LondonSouthBankUniversity/LSBU - Jose's Collaborative Projects/Norfolk and Waveney CHPPD/2025 November/Data Engineering/Data/2-clean_data_trust_level with all hospitals.xlsx", index=False)  # Optional: save to a new Excel file

# %% [markdown]
# # 1- Data Cleaning

# %%
import pandas as pd

# Assuming df is your DataFrame

# Filtering the DataFrame
norfolk_waveney_samples = df[df['Organisation Name'].str.startswith('Norfolk') | 
                df['Organisation Name'].str.startswith('James') |
                df['Organisation Name'].str.contains('Queen Elizabeth')|
                df['Organisation Name'].str.startswith('NORFOLK') | 
                df['Organisation Name'].str.startswith('JAMES') |
                df['Organisation Name'].str.contains('QUEEN ELIZABETH') ]

# Displaying the filtered DataFrame
norfolk_waveney_samples
# Out:
#                               Organisation Name Organisation Code  \
# 21                          Norfolk And Suffolk               RMY
# 106    Norfolk And Norwich University Hospitals               RM1
# 108            James Paget University Hospitals               RGP
# 150        Queen Elizabeth Hospital King’S Lynn               RCX
# 178           Norfolk Community Health And Care               RY3
# ...                                         ...               ...
# 10376      Queen Elizabeth Hospital King’S Lynn               RCX
# 10393          James Paget University Hospitals               RGP
# 10423  Norfolk And Norwich University Hospitals               RM1
# 10427                       Norfolk And Suffolk               RMY
# 10513         Norfolk Community Health And Care               RY3
#
#        CHPPD - Overall  \
# 21               10.39
# 106               7.63
# 108               7.94
# 150               6.92
# 178               7.33
# ...                ...
# ...

# %% [markdown]
# # Organisation Name

# %%
unique_categories = norfolk_waveney_samples['Organisation Name'].unique()
unique_categories
# Out:
# array(['Norfolk And Suffolk', 'Norfolk And Norwich University Hospitals',
#        'James Paget University Hospitals',
#        'Queen Elizabeth Hospital King’S Lynn',
#        'Norfolk Community Health And Care'], dtype=object)

# %%
replacement_dict = {
    'James Paget University Hospitals NHS Foundation Trust': 'James Paget University Hospitals NHS Foundation Trust',
    'James Paget University Hospitals': 'James Paget University Hospitals NHS Foundation Trust',
    'JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION TRUST': 'James Paget University Hospitals NHS Foundation Trust',
    'Norfolk Community Health And Care NHS Trust': 'Norfolk Community Health And Care NHS Trust',
    'Norfolk Community Health And Care': 'Norfolk Community Health And Care NHS Trust',
    'NORFOLK COMMUNITY HEALTH AND CARE NHS TRUST': 'Norfolk Community Health And Care NHS Trust',
    'Norfolk And Norwich University Hospitals NHS Foundation Trust': 'Norfolk And Norwich University Hospitals NHS Foundation Trust',
    'Norfolk And Norwich University Hospitals': 'Norfolk And Norwich University Hospitals NHS Foundation Trust',
    'NORFOLK AND NORWICH UNIVERSITY HOSPITALS NHS FOUNDATION TRUST': 'Norfolk And Norwich University Hospitals NHS Foundation Trust',
    'Norfolk And Suffolk NHS Foundation Trust': 'Norfolk And Suffolk NHS Foundation Trust',
    'Norfolk And Suffolk': 'Norfolk And Suffolk NHS Foundation Trust',
    'NORFOLK AND SUFFOLK NHS FOUNDATION TRUST': 'Norfolk And Suffolk NHS Foundation Trust',
    "The Queen Elizabeth Hospital, King's Lynn, NHS Foundation Trust": "The Queen Elizabeth Hospital King's Lynn NHS Foundation Trust",
    "Queen Elizabeth Hospital King’S Lynn": "The Queen Elizabeth Hospital King's Lynn NHS Foundation Trust",
    "THE QUEEN ELIZABETH HOSPITAL, KING'S LYNN, NHS FOUNDATION TRUST": "The Queen Elizabeth Hospital King's Lynn NHS Foundation Trust"}
    

# Use .replace() function to replace categories
norfolk_waveney_samples['Organisation Name'] = norfolk_waveney_samples['Organisation Name'].replace(replacement_dict)

# Display the DataFrame after replacement
# Out:
# /var/folders/4_/wj3d4rr14vb32p3pr2705k9mjbk4dm/T/ipykernel_48350/1837114984.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norfolk_waveney_samples['Organisation Name'] = norfolk_waveney_samples['Organisation Name'].replace(replacement_dict)

# %%
unique_categories = norfolk_waveney_samples['Organisation Name'].unique()
unique_categories
# Out:
# array(['Norfolk And Suffolk NHS Foundation Trust',
#        'Norfolk And Norwich University Hospitals NHS Foundation Trust',
#        'James Paget University Hospitals NHS Foundation Trust',
#        "The Queen Elizabeth Hospital King's Lynn NHS Foundation Trust",
#        'Norfolk Community Health And Care NHS Trust'], dtype=object)

# %%
# Get the unique values and their counts
unique_values_counts = norfolk_waveney_samples['Organisation Name'].value_counts()

# Display the unique values and their counts
unique_values_counts
# Out:
# Organisation Name
# Norfolk And Suffolk NHS Foundation Trust                         56
# Norfolk And Norwich University Hospitals NHS Foundation Trust    56
# James Paget University Hospitals NHS Foundation Trust            56
# Norfolk Community Health And Care NHS Trust                      56
# The Queen Elizabeth Hospital King's Lynn NHS Foundation Trust    55
# Name: count, dtype: int64

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ### Create variable year and month

# %%
# Split 'year_month' column into 'year' and 'month' columns
norfolk_waveney_samples=norfolk_waveney_samples.copy()
#Split 'year_month' column into 'year' and 'month' columns
norfolk_waveney_samples[['year', 'month']] = norfolk_waveney_samples['year_month'].str.split('-', expand=True)

# Convert 'year' and 'month' columns to appropriate data types (optional)
norfolk_waveney_samples['year'] = norfolk_waveney_samples['year'].astype(int)
norfolk_waveney_samples['month'] = norfolk_waveney_samples['month'].astype(int)

# %%
norfolk_waveney_samples
# Out:
#                                        Organisation Name Organisation Code  \
# 21              Norfolk And Suffolk NHS Foundation Trust               RMY
# 106    Norfolk And Norwich University Hospitals NHS F...               RM1
# 108    James Paget University Hospitals NHS Foundatio...               RGP
# 150    The Queen Elizabeth Hospital King's Lynn NHS F...               RCX
# 178          Norfolk Community Health And Care NHS Trust               RY3
# ...                                                  ...               ...
# 10376  The Queen Elizabeth Hospital King's Lynn NHS F...               RCX
# 10393  James Paget University Hospitals NHS Foundatio...               RGP
# 10423  Norfolk And Norwich University Hospitals NHS F...               RM1
# 10427           Norfolk And Suffolk NHS Foundation Trust               RMY
# 10513        Norfolk Community Health And Care NHS Trust               RY3
#
#        CHPPD - Overall  \
# 21               10.39
# ...

# %%
# Specify the file path where you want to save the Excel file
file_path = r"/Users/e410675/Library/CloudStorage/OneDrive-LondonSouthBankUniversity/LSBU - Jose's Collaborative Projects/Norfolk and Waveney CHPPD/2025 November/Data Engineering/Data/clean_data_trust_level.xlsx"

# Save the DataFrame to Excel
#norfolk_waveney_samples.to_excel(file_path, index=False)  # Set index=False if you don't want to include row numbers

print("DataFrame saved to Excel successfully.")
# Out:
# DataFrame saved to Excel successfully.
